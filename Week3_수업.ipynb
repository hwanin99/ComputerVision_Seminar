# %% [markdown]
# <a href="https://colab.research.google.com/github/hwanin99/ComputerVision_Seminar/blob/main/Week3_%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image as PILImage
import matplotlib.pyplot as plt
import glob

fig=plt.figure(figsize=(10,10))

dolphin_img_list = glob.glob('/content/drive/MyDrive/CV_seminar_project/original/dolphin/*')
shark_img_list = glob.glob('/content/drive/MyDrive/CV_seminar_project/original/shark/*')
whale_img_list = glob.glob('/content/drive/MyDrive/CV_seminar_project/original/whale/*')

# %%
img_1=cv2.imread(dolphin_img_list[0]) # -> (H,W,C) : C축이 RGB가 아니라 BGR
img_1.shape # (251,201,3)

cv2_imshow(img_1) # cv2.imshow 코랩에서 불가 -> cv2_imshow
# Out:
# <PIL.Image.Image image mode=RGB size=201x251 at 0x7F7D9C3CE370>

# %%
plt.imshow(img_1)

# %%
plt.imshow(img_1[:,:,::-1]) # BGR -> RGB

# %%
PILImage.open(dolphin_img_list[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x251 at 0x7F7DBCBD80A0>

# %%
plt.imshow(img_1[:,:,0])

# %%
plt.imshow(img_1[:,:,1])

# %%
plt.imshow(img_1[:,:,2]) # BGR이니까 B -> [:,:,0], G -> [:,:,1], R -> [:,:,2]

# %%
plt.imshow(img_1[:150,:150,::-1])

# %%
plt.imshow(img_1[150:,150:,::-1])

# %%
import numpy as np
np.max(img_1) # 이미지 데이터 특성 -> 0~255 -> 0에 가까울수록 검은색, 1에 가까울수록 흰색
# Out:
# 255

# %%
img_3=cv2.imread(dolphin_img_list[10])
img_3
# Out:
# array([[[205, 204, 194],
#         [204, 203, 193],
#         [202, 202, 190],
#         ...,
#         [117,  53,   0],
#         [117,  53,   0],
#         [117,  53,   0]],
#
#        [[198, 197, 187],
#         [196, 196, 184],
#         [195, 193, 182],
#         ...,
#         [117,  53,   0],
#         [117,  53,   0],
#         [117,  53,   0]],
#
#        [[188, 186, 175],
#         [187, 186, 172],
#         [186, 183, 169],
#         ...,
#         [118,  52,   0],
#         [118,  52,   0],
#         [118,  52,   0]],
#
#        ...,
#
#        [[123,  49,   1],
#         [123,  49,   1],
#         [123,  49,   1],
#         ...,
#         [ 71,  22,   0],
#         [ 71,  22,   0],
#         [ 71,  22,   0]],
#
#        [[120,  48,   1],
#         [120,  48,   1],
#         [120,  48,   1],
#         ...,
#         [ 70,  21,   0],
#         [ 70,  21,   0],
#         [ 70,  21,   0]],
#
#        [[120,  48,   1],
#         [120,  48,   1],
#         [120,  48,   1],
# ...
